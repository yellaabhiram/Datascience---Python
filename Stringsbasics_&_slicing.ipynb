# %% [markdown]
# <a href="https://colab.research.google.com/github/yellaabhiram/Datascience---Python/blob/main/Stringsbasics_%26_slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **String as a data type**

# %%
# string si a seqence of chars
# sequence of unocde chars
# creating the strings
# accessing the strings
# adding chars to the strings Editing the strings
# deleting the cstrings
# STRING operations and functions
c = "Hello"
print(c)

# %%
c = '''hello
gape
filled '''
# multiline strings case we write

# %%
# accessing the substrings from the string
# indexing and slicing
name = "Hello"
print(name[2:4])
# Out:
# ll

# %%
# slicing what if I want to take out a sbustring out of it
c = "Hello-  world"
print(c[0:3])
# Out:
# Hel

# %%
print(c[:7])
# Out:
# Hello-

# %%
document = "data scince"
document[0:5]
# step size
document[0:9:3]
# Out:
# 'dac'

# %%
document[-2:-6:-2]
# Out:
# 'ci'

# %%
document[::-1]
# Out:
# 'ecnics atad'

# %%
document[-5:-1:1]
# Out:
# 'cinc'
