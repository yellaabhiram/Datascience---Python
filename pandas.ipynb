# %% [markdown]
# **Pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with structured (tabular, multidimensional, potentially heterogeneous) and time series data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.**
#
# >> Pandas is designed to make it easier to work with structured data. Most of the analyses you might perform will likely involve using tabular data, e.g., from .csv files or relational databases (e.g., SQL). The DataFrame object in pandas is "a two-dimensional tabular, column-oriented data structure with both row and column labels."
#
# **Here are just a few of the things that pandas does well:**
#
# * Robust IO tools for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format
#
# * Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data
#
# * size mutabiltiy: columns can be inserted and deleted from DataFrame and higher dimensional objects
#
# * Automatic and explicit data alignment: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
#
# * Powerful, flexible group by functionality to perform split-apply-combine operations on data sets, for both aggregating and transforming data
#
# * Make it easy to convert ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
#
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets
# * Intuitive merging and joining data sets
# * Flexible reshaping and pivoting of data sets
# * Hierarchical labeling of axes (possible to have multiple labels per tick)

# %%
# the data which is stored in rows and cols structured data

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# **Pandas DataFrames**
#
# * In this chapter, you will learn about Pandas dataframes, a data structure in Python that provides the ability to work with tabular data. Pandas dataframes are composed of rows and columns that can have header names, and the columns in pandas dataframes can be different types (e.g. the first column containing integers and the second column containing text strings). Each value in pandas dataframe is referred to as a cell that has a specific row index and column index within the tabular structure.

# %%
# series : it is essentiallty a column
# DataFrame : A 2 D data scturcture, ie data  is allingend in tablular fasion of rows and colns
# pandas data frame : Series + series  = Dataframe

# %%
# first series
number_series  = pd.Series([1,2,3,4,5], name = "series of nums")
number_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: series of nums, dtype: int64

# %%
# first series
number_series  = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'] , name = "series of nums")
number_series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: series of nums, dtype: int64

# %%
number_series['a']
# Out:
# 1

# %%
number_series[0]
# Out:
# <ipython-input-7-6a2408185e6e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   number_series[0]
# 1

# %%
# using 2 d array create dataframe
# creating our firstr dataframe

some_random_2darray = np.random.randint(4,6, size = (4,3))
some_random_2darray
# Out:
# array([[4, 4, 4],
#        [5, 4, 4],
#        [4, 5, 4],
#        [4, 5, 4]])

# %%
first_dataframe = pd.DataFrame(some_random_2darray)
first_dataframe
# Out:
#    0  1  2
# 0  4  4  4
# 1  5  4  4
# 2  4  5  4
# 3  4  5  4

# %%
first_dataframe = pd.DataFrame(some_random_2darray, columns = ['sam','karan','soumya'])
first_dataframe
# Out:
#    sam  karan  soumya
# 0    4      4       4
# 1    4      4       5
# 2    4      5       5
# 3    4      4       4

# %%
first_dataframe = pd.DataFrame(some_random_2darray, index = ["Maths","Science","Python", "Geo"], columns = ['sam','karan','soumya'])
first_dataframe
# Out:
#          sam  karan  soumya
# Maths      4      4       4
# Science    4      4       5
# Python     4      5       5
# Geo        4      4       4

# %%
# list of lists

list_of_lists = [['Amar',10],['Suhani',20],["Sam",21]]
list_of_lists
# Out:
# [['Amar', 10], ['Suhani', 20], ['Sam', 21]]

# %%
df = pd.DataFrame(list_of_lists, columns=['Name','Age'])
df

# add index names also
# Out:
#      Name  Age
# 0    Amar   10
# 1  Suhani   20
# 2     Sam   21

# %%
# using dict
employee_dict = {"Employee_Name":["Amar","Suhani","Sam"], "Income":[100000,200000,210000]}
employee_dict
# Out:
# {'Employee_Name': ['Amar', 'Suhani', 'Sam'],
#  'Income': [100000, 200000, 210000]}

# %%
df = pd.DataFrame(employee_dict)
df
# Out:
#   Employee_Name  Income
# 0          Amar  100000
# 1        Suhani  200000
# 2           Sam  210000

# %%
# Store the data in a dictionary
series_dict = {'First Series' : pd.Series([10, 20, 30, 40]),
              'Second Series' : pd.Series([10, 20, 30, 40])}

df = pd.DataFrame(series_dict)
df
# Out:
#    First Series  Second Series
# 0            10             10
# 1            20             20
# 2            30             30
# 3            40             40

# %%
list_of_dicts = [{'a': 1, 'b': 2, 'c':3}, {'a':10, 'b': 20, 'c': 30}]
df = pd.DataFrame(list_of_dicts)
df
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
# there are other ways

actor_names = ['Ryan Reynolds', 'Benedict Cumberbatch', 'Robert Downey Jr.', 'Chris Evans']
actor_ages = [48,52,54,np.nan]

list_of_tuples = list(zip(actor_names, actor_ages))
list_of_tuples
# Out:
# [('Ryan Reynolds', 48),
#  ('Benedict Cumberbatch', 52),
#  ('Robert Downey Jr.', 54),
#  ('Chris Evans', nan)]

# %%
actor_df = pd.DataFrame(list_of_tuples, columns = ['Name', 'Age'])
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  52.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
# methods and attributes avaailable with pandas

list(actor_df.index)
# Out:
# [0, 1, 2, 3]

# %%
our_array = np.random.randn(100,5)

df = pd.DataFrame(our_array, columns=['a','b','c','d','e'])
df
# Out:
#            a         b         c         d         e
# 0   0.689732 -0.441533 -1.566720 -1.305102  1.488827
# 1   0.972996 -0.697384  0.936675 -0.905168 -1.244499
# 2   1.095078  0.816651 -1.047648  1.001697  0.913357
# 3  -0.343686  0.061762  0.281473 -0.512103  1.513370
# 4  -1.987919 -0.104541 -0.505185  0.726719 -0.636738
# ..       ...       ...       ...       ...       ...
# 95  0.145296  0.971073 -0.691603  0.793521 -0.415297
# 96 -1.059070 -0.004186 -0.040187 -0.405093  1.103875
# 97  0.296187  0.080375 -1.393169  1.051584  1.827699
# 98 -0.709627 -0.081541 -0.795437 -0.460072 -1.176079
# 99  1.111060  1.272185 -0.198456 -0.469920 -0.376288
#
# [100 rows x 5 columns]

# %%
# head()

df.head()
# Out:
#           a         b         c         d         e
# 0  0.689732 -0.441533 -1.566720 -1.305102  1.488827
# 1  0.972996 -0.697384  0.936675 -0.905168 -1.244499
# 2  1.095078  0.816651 -1.047648  1.001697  0.913357
# 3 -0.343686  0.061762  0.281473 -0.512103  1.513370
# 4 -1.987919 -0.104541 -0.505185  0.726719 -0.636738

# %%
df.head(10) # we can also print first n rows
# Out:
#           a         b         c         d         e
# 0  0.689732 -0.441533 -1.566720 -1.305102  1.488827
# 1  0.972996 -0.697384  0.936675 -0.905168 -1.244499
# 2  1.095078  0.816651 -1.047648  1.001697  0.913357
# 3 -0.343686  0.061762  0.281473 -0.512103  1.513370
# 4 -1.987919 -0.104541 -0.505185  0.726719 -0.636738
# 5 -1.180202  2.514153 -0.773019  0.626093 -0.269101
# 6  0.582276  1.535292 -0.711452  1.569780 -0.912344
# 7  0.272911  0.819704 -1.423378 -2.546345 -0.281139
# 8  0.137165 -1.185896  1.848909  1.657037  1.640948
# 9 -0.301471 -1.423571 -0.962665  0.945914 -0.120877

# %%
# columns
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# info()
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  52.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 192.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       100 non-null    float64
#  1   b       100 non-null    float64
#  2   c       100 non-null    float64
#  3   d       100 non-null    float64
#  4   e       100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
# rename() easily yopu cn rename the colus
actor_df
# Out:
#                    Name   Age
# 0         Ryan Reynolds  48.0
# 1  Benedict Cumberbatch  52.0
# 2     Robert Downey Jr.  54.0
# 3           Chris Evans   NaN

# %%
actor_df.rename(columns = {'Name':'Actor_Name', 'Age':'Actor_Age'},inplace=True)

# %%
actor_df
# Out:
#              Actor_Name  Actor_Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       52.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
actor_df = actor_df.rename({'Actor_Name':'Name'},axis=1)
actor_df
# Out:
#                    Name  Actor_Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       52.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
actor_df
# Out:
#                    Name  Actor_Age
# 0         Ryan Reynolds       48.0
# 1  Benedict Cumberbatch       52.0
# 2     Robert Downey Jr.       54.0
# 3           Chris Evans        NaN

# %%
df = pd.read_csv("/content/imdb_data.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-33-6b66fe90bb73> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/imdb_data.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.689732 -0.441533 -1.566720 -1.305102  1.488827
# 1  0.972996 -0.697384  0.936675 -0.905168 -1.244499
# 2  1.095078  0.816651 -1.047648  1.001697  0.913357
# 3 -0.343686  0.061762  0.281473 -0.512103  1.513370
# 4 -1.987919 -0.104541 -0.505185  0.726719 -0.636738

# %%
df.shape
# Out:
# (100, 5)

# %%
df_bigmart = pd.read_csv("/content/big_mart.csv")

# %%
df_bigmart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# **Up till now, we have been creating our own simple dataframes and exploring them. But of course life is not that simple. Most of the data you would deal with in your jobs would be a lot bigger and messier. Let us start with first loading these data in our Python environment.**

# %%
# 80% od the work is of data prepration !
# machine leanirng
# deep leanirng 2 lines of code

# %%
df_sentiment = pd.read_csv("https://raw.githubusercontent.com/Ankit152/IMDB-sentiment-analysis/refs/heads/master/IMDB-Dataset.csv")

# %%
df_sentiment.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df_new = pd.read_csv("https://raw.githubusercontent.com/LearnDataSci/articles/refs/heads/master/Python%20Pandas%20Tutorial%20A%20Complete%20Introduction%20for%20Beginners/IMDB-Movie-Data.csv")

# %%
df_new.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df_bigmart = pd.read_csv("/content/big_mart.csv")

# %%
df_bigmart.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df_bigmart.value_counts("Outlet_Size")

# 94 number !
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df_bigmart.info()
# resources you have to be optimized
# gpu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# where people prefer to go ? d mart ! dukan  6000 2000 , what if out of 8500 7500 null values hote? 2000

# %%
#describe() method

df_bigmart.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df = pd.read_csv("/content/imdb_data.csv")

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df["crew"][0]
# Out:
# '[{\'credit_id\': \'59ac067c92514107af02c8c8\', \'department\': \'Directing\', \'gender\': 0, \'id\': 1449071, \'job\': \'First Assistant Director\', \'name\': \'Kelly Cantley\', \'profile_path\': None}, {\'credit_id\': \'52fe4ee7c3a36847f82afad7\', \'department\': \'Directing\', \'gender\': 2, \'id\': 3227, \'job\': \'Director\', \'name\': \'Steve Pink\', \'profile_path\': \'/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg\'}, {\'credit_id\': \'5524ed25c3a3687ded000d88\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Writer\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed2d925141720c001128\', \'department\': \'Writing\', \'gender\': 2, \'id\': 347335, \'job\': \'Characters\', \'name\': \'Josh Heald\', \'profile_path\': \'/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg\'}, {\'credit_id\': \'5524ed3d92514166c1004a5d\', \'department\': \'Production\', \'gender\': 2, \'id\': 57822, \'job\': \'Producer\', \'name\': \'Andrew Panay\',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# **Indexing and Slicing**
# >> loc and iloc methods

# %% [markdown]
# **iloc gets rows (or columns) at particular positions in the index (so it only takes integers).**
# 1. The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column.
# **loc is label based data selecting method, you need to pass the name of row or the coumn that you want to work with**

# %%
# importing the module
import pandas as pd

# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
                               'Mahindra', 'Maruti', 'Hyundai',
                               'Renault', 'Tata', 'Maruti'],
                     'Year': [2012, 2014, 2011, 2015, 2012,
                              2016, 2014, 2018, 2019],
                     'Kms Driven': [50000, 30000, 60000,
                                    25000, 10000, 46000,
                                    31000, 15000, 12000],
                     'City': ['Gurgaon', 'Delhi', 'Mumbai',
                              'Delhi', 'Mumbai', 'Delhi',
                              'Mumbai', 'Chennai',  'Ghaziabad'],
                     'Mileage':  [28, 27, 25, 26, 28,
                                  29, 24, 21, 24]})

# displaying the DataFrame
display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
# selct the cars which have the brand maruti and milage > 25
# selecting cars with brand 'Maruti' and Mileage > 25
display(data.loc[(data.Brand == 'Maruti') & (data.Mileage > 25)])
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 4  Maruti  2012       10000   Mumbai       28

# %%
# Example 2: Selecting a Range of Rows From the DataFrame
display(data.loc[2: 5])
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
# updating values of Mileage if Year < 2015
data.loc[(data.Year < 2015), ['Mileage']] = 22
display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       22
# 1   Hyundai  2014       30000      Delhi       22
# 2      Tata  2011       60000     Mumbai       22
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       22
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       22
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
# selecting 0th, 2nd, 4th, and 7th index rows
display(data.iloc[[0, 2, 4, 7]])
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       22
# 2    Tata  2011       60000   Mumbai       22
# 4  Maruti  2012       10000   Mumbai       22
# 7    Tata  2018       15000  Chennai       21

# %%
data.iloc[1:10, 2:5]
# Out:
#    Kms Driven       City  Mileage
# 1       30000      Delhi       22
# 2       60000     Mumbai       22
# 3       25000      Delhi       26
# 4       10000     Mumbai       22
# 5       46000      Delhi       29
# 6       31000     Mumbai       22
# 7       15000    Chennai       21
# 8       12000  Ghaziabad       24

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.iloc[:, -3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# ...

# %%
# loc gets rows (or columns) with particular labels from the index.
df.loc[50:60, ['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 50     560000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...    102.0
# 51   12000000  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...    160.0
# 52          0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...     97.0
# 53          0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...     98.0
# 54   20000000                     [{'id': 28, 'name': 'Action'}]    107.0
# 55          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     95.0
# 56          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     97.0
# 57  125000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    125.0
# 58          0  [{'id': 10402, 'name': 'Music'}, {'id': 10749,...     95.0
# 59   14000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     95.0
# 60  150000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...    144.0

# %%
new_df = df[['original_language','release_date','cast']]

# %%
new_df.head()
# Out:
#   original_language release_date  \
# 0                en      2/20/15
# 1                en       8/6/04
# 2                en     10/10/14
# 3                hi       3/9/12
# 4                ko       2/5/09
#
#                                                 cast
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...

# %%
# in pandas we can perform boolean indexing

df["original_language"] == "en"
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
english_movies = df[df["original_language"] == "en"]
english_movies
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 5        6                                                NaN   8000000
# 6        7                                                NaN  14000000
# ...    ...                                                ...       ...
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection    budget  \
# 3    4                   NaN   1200000
# 4    5                   NaN         0
# 15  16                   NaN    500000
# 30  31                   NaN  13000000
# 31  32                   NaN         0
#
#                                                genres  \
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
#
#                                  homepage    imdb_id original_language  \
# 3              http://kahaanithefilm.com/  tt1821480                hi
# 4                                     NaN  tt1380152                ko
# 15  http://skinningmovie.com/synopsis.htm  tt1129437                sr
# 30                                    NaN  tt1675434                fr
# ...

# %%
long_movies = df[df['runtime'] >= 120]
long_movies[["title","cast"]]
# Out:
#                         title  \
# 3                     Kahaani
# 12            American Beauty
# 14            Minority Report
# 20              Lost in Space
# 33            ABCs of Death 2
# ...                       ...
# 2970            The Bodyguard
# 2980         Action Hero Biju
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2997  The Long Kiss Goodnight
#
#                                                    cast
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 12    [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14    [{'cast_id': 5, 'character': 'Chief John Ander...
# 20    [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33    [{'cast_id': 60, 'character': 'Assassin (Segme...
# ...                                                 ...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# ...

# %%
# print all the en movies having runtime > 120

(df['original_language'] == 'en') & (df['runtime'] >120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
long_english_movies = df[(df['original_language'] == 'en') & (df['runtime'] >120)]
long_english_movies
# Out:
#         id                              belongs_to_collection     budget  \
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37      38                                                NaN   50000000
# ...    ...                                                ...        ...
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...    2000000
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
#
#                                                  genres  \
# ...

# %%
# how can we manipulate the columns
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
df['new_runtime'] = df['runtime'] * 0.5

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df["movie_profit"] = df["revenue"] - df["budget"]

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
# drop the columns
df.drop(columns = ['id'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.drop(["new_runtime", "poster_path"],axis = 1, inplace=True)

# %%
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                NaN   3300000
# 3                                                NaN   1200000
# 4                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
# perfom all the basic operation
df["budget"].sum()
# Out:
# 67594002330

# %%
df["budget"].mean()
# Out:
# 22531334.11

# %%
df.set_index("imdb_id", inplace=True)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# ...

# %%
df["budget"][1:5].sum()
# Out:
# 44500000

# %%
# apply() to every col

# conver col to uppercase()
def to_uppercase(column):
  return column.upper()

# %%
df["capitalized_title"] = df["title"].apply(to_uppercase)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# ...

# %%
def add_two_numbers(a,b):
  return a+b

# %%
x = lambda a,b : a+b
x(1,5)
# Out:
# 6

# %%
add_two_numbers(1,2)
# Out:
# 3

# %%
def revised_profit(revenue, budget):
  if revenue>0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df["new_profit"] = df.apply(lambda x : revised_profit(x["revenue"], x["budget"]), axis = 1)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# ...

# %%
# we can sort the dataframes in acending and decending order
df.sort_values("new_profit", ascending=False)
# Out:
#                                        belongs_to_collection     budget  \
# imdb_id
# tt2820852  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# tt0848228  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# tt2395427  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# tt2771200                                                NaN  160000000
# tt1399103  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# ...                                                      ...        ...
# tt0455824                                                NaN  130000000
# tt2361317                                                NaN  108000000
# tt0112760                                                NaN   98000000
# tt0180052                                                NaN  100000000
# tt2239822                                                NaN  197471676
#
#                                                       genres  \
# imdb_id
# ...

# %%
# sort multiple colum
df.sort_values(['status','new_profit'], ascending=[False,True]).head()
# Out:
#                                        belongs_to_collection     budget  \
# imdb_id
# tt0145394                                                NaN     891000
# tt1860180                                                NaN          0
# tt0120254  [{'id': 144200, 'name': 'Swan Princess Series'...          0
# tt0091024                                                NaN          0
# tt2239822                                                NaN  197471676
#
#                                                       genres homepage  \
# imdb_id
# tt0145394                [{'id': 99, 'name': 'Documentary'}]      NaN
# tt1860180                     [{'id': 35, 'name': 'Comedy'}]      NaN
# tt0120254  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...      NaN
# tt0091024  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN
# tt2239822  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      NaN
#
#           original_language                                  original_title  \
# imdb_id
# ...

# %% [markdown]
# **Let us explore some datetime operations and functions**
#
# * %a Weekday as locale’s abbreviated name. Sun, Mon, …, Sat (en_US)So, Mo, …, Sa (de_DE)
# * %A Weekday as locale’s full name. Sunday, Monday, …, Saturday (en_US)Sonntag, Montag, …, Samstag (de_DE)
# * %w Weekday as a decimal number, where 0 is Sunday and 6 is Saturday. 0, 1, 2, 3, 4, 5, 6
# * %d Day of the month as a zero-padded decimal number. 01, 02, …, 31
# * %b Month as locale’s abbreviated name. Jan, Feb, …, Dec (en_US)Jan, Feb, …, Dez (de_DE)
# *%B Month as locale’s full name. January, February, …, December (en_US)Januar, Februar, …, Dezember (de_DE)
# * %m Month as a zero-padded decimal number. 01, 02 … 12
# *%y Year without century as a zero-padded decimal number. 01, 02, … 99
# * %Y Year with century as a decimal number. 0001, 0002, … , 9999
# * %H Hour (24-hour clock) as a zero-padded decimal number. 01, 02, … , 23
# * %I Hour (12-hour clock) as a zero-padded decimal number. 01, 02, … , 12
# * %p Locale’s equivalent of either AM or PM. AM, PM (en_US)
# * %M Minute as a zero-padded decimal number. 01, 02, … , 59
# * %S Second as a zero-padded decimal number. 01, 02, … , 59
# * %f Microsecond as a decimal number, zero-padded on the left. 000000, 000001, …, 999999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
# ...

# %%
df['release_date']
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
#                ...
# tt0109403     4/22/94
# tt2364975     3/28/13
# tt0116908    10/11/96
# tt0343135     1/16/04
# tt1600195     9/22/11
# Name: release_date, Length: 3000, dtype: object

# %%
from datetime import datetime
from datetime import date

# %% [markdown]
# * strptime means string parser, this will convert a string format to datetime.
# * strftime means string formatter, this will format a datetime object to string format.

# %%
df['release_date'][0:5]
# Out:
# imdb_id
# tt2637294     2/20/15
# tt0368933      8/6/04
# tt2582802    10/10/14
# tt1821480      3/9/12
# tt1380152      2/5/09
# Name: release_date, dtype: object

# %%
df["new_release_date"] = df["release_date"].apply(lambda x : datetime.strptime(x, "%m/%d/%y"))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
# ...

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                                NaN                en
# ...

# %%
df['new_release_date'][0]
# Out:
# <ipython-input-74-007681be0d59>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['new_release_date'][0]
# Timestamp('2015-02-20 00:00:00')

# %%
# month year and date
print(df["new_release_date"][0].month)
print(df["new_release_date"][0].year)
print(df["new_release_date"][0].day)
print(df["new_release_date"][0].hour)
print(df["new_release_date"][0].minute)
print(df["new_release_date"][0].second)
# Out:
# 2
# 2015
# 20
# 0
# 0
# 0
# <ipython-input-77-15ddeb870fed>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df["new_release_date"][0].month)
# <ipython-input-77-15ddeb870fed>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df["new_release_date"][0].year)
# <ipython-input-77-15ddeb870fed>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(df["new_release_date"][0].day)
# ...

# %%
print(date.today())
# Out:
# 2024-12-14

# %%
print(datetime.now())
# Out:
# 2024-12-14 04:36:34.328770

# %% [markdown]
# **Let's explore the unique and missing values**
#
# * unique()
# * nunique()
# * value_counts()
# * isnull()
# * fillna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
# ...

# %%
# find unique values in a column
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
df['status']
# Out:
# imdb_id
# tt2637294    Released
# tt0368933    Released
# tt2582802    Released
# tt1821480    Released
# tt1380152    Released
#                ...
# tt0109403    Released
# tt2364975    Released
# tt0116908    Released
# tt0343135    Released
# tt1600195    Released
# Name: status, Length: 3000, dtype: object

# %%
# 3000 values : 100 missing 2900 non null : 100 values i need to fill them  , what can he the most appropriate way to fill this values ! list , 600 , 100!

# %%
list(df["original_language"].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()
# Out:
# 36

# %%
df["original_language"].value_counts() # is all about the predic 100%
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df["runtime"].value_counts()
# Out:
# runtime
# 90.0     100
# 100.0     99
# 105.0     91
# 95.0      89
# 98.0      85
#         ...
# 220.0      1
# 60.0       1
# 53.0       1
# 185.0      1
# 182.0      1
# Name: count, Length: 139, dtype: int64

# %%
df["homepage"].value_counts()
# Out:
# homepage
# http://www.transformersmovie.com/               4
# http://www.thehobbit.com/                       2
# http://www.lordoftherings.net/                  2
# http://sonyclassics.com/whiplash/               1
# https://www.facebook.com/thefinesthoursmovie    1
#                                                ..
# http://admiralfilm.ru/                          1
# http://www.jackreachermovie.com/                1
# http://www.sleepdealer.com/                     1
# http://www.popperspenguins.com/main.html        1
# http://www.abductionthefilm.com/                1
# Name: count, Length: 941, dtype: int64

# %%
df["homepage"].isnull().sum()
# Out:
# 0

# %%
# Lets fill the missing values with the value -999
df['homepage'].fillna('Not Present',inplace = True)
# Out:
# <ipython-input-91-21d792dee427>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['homepage'].fillna('Not Present',inplace = True)

# %%
df.fillna({"homepage": "Not Present"}, inplace=True)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                        Not Present                en
# ...

# %%
df["revenue"]
# Out:
# imdb_id
# tt2637294     12314651
# tt0368933     95149435
# tt2582802     13092000
# tt1821480     16000000
# tt1380152      3923970
#                ...
# tt0109403      1596687
# tt2364975       180590
# tt0116908     89456761
# tt0343135    171963386
# tt1600195     82087155
# Name: revenue, Length: 3000, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               3000 non-null   object
#  4   original_language      3000 non-null   object
#  5   original_title         3000 non-null   object
#  6   overview               2992 non-null   object
#  7   popularity             3000 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2945 non-null   object
#  10  release_date           3000 non-null   object
#  11  runtime                2998 non-null   float64
#  12  spoken_languages       2980 non-null   object
#  13  status                 3000 non-null   object
# ...

# %%
df["genres"].isnull().sum()
# Out:
# 0

# %%
df.dropna(subset = ["genres"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2993 entries, tt2637294 to tt1600195
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 2993 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               2993 non-null   object
#  4   original_language      2993 non-null   object
#  5   original_title         2993 non-null   object
#  6   overview               2985 non-null   object
#  7   popularity             2993 non-null   float64
#  8   production_companies   2844 non-null   object
#  9   production_countries   2941 non-null   object
#  10  release_date           2993 non-null   object
#  11  runtime                2991 non-null   float64
#  12  spoken_languages       2976 non-null   object
#  13  status                 2993 non-null   object
# ...

# %%
# how to handle the outliers

df.describe()
# Out:
#              budget   popularity      runtime       revenue  movie_profit  \
# count  2.993000e+03  2993.000000  2991.000000  2.993000e+03  2.993000e+03
# mean   2.258209e+07     8.482164   107.851555  6.687931e+07  4.429722e+07
# min    0.000000e+00     0.000001     0.000000  1.000000e+00 -1.074474e+08
# 25%    0.000000e+00     4.071187    94.000000  2.405420e+06  2.066600e+04
# 50%    8.000000e+06     7.392294   104.000000  1.692814e+07  6.166819e+06
# 75%    2.900000e+07    10.896238   118.000000  6.905570e+07  4.183723e+07
# max    3.800000e+08   294.337037   338.000000  1.519558e+09  1.316249e+09
# std    3.705444e+07    12.111833    22.085756  1.376564e+08  1.124387e+08
#
#          new_profit               new_release_date
# count  2.993000e+03                           2993
# mean   4.429722e+07  2005-02-06 23:06:35.723354624
# min   -1.074474e+08            1969-01-01 00:00:00
# 25%    2.066600e+04            1995-10-27 00:00:00
# ...

# %%
df.drop(columns = ["new_release_date"], inplace=True)

# %%
df.head()
# Out:
#                                        belongs_to_collection    budget  \
# imdb_id
# tt2637294  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# tt0368933  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# tt2582802                                                NaN   3300000
# tt1821480                                                NaN   1200000
# tt1380152                                                NaN         0
#
#                                                       genres  \
# imdb_id
# tt2637294                     [{'id': 35, 'name': 'Comedy'}]
# tt0368933  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# tt2582802                      [{'id': 18, 'name': 'Drama'}]
# tt1821480  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# tt1380152  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                     homepage original_language  \
# imdb_id
# tt2637294                        Not Present                en
# ...
